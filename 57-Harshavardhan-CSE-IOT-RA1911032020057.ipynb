# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('GeneralEsportData.csv')

# %%
dataset
# Out:
#                                              Game  ReleaseDate  \
# 0                                  Age of Empires         1997
# 1                               Age of Empires II         1999
# 2                              Age of Empires III         2005
# 3                               Age of Empires IV         2021
# 4                           Age of Empires Online         2011
# ..                                            ...          ...
# 542                Gears of War: Ultimate Edition         2015
# 543                                 Knockout City         2021
# 544  Mobile Suit Gundam: Extreme Vs Maxi Boost ON         2016
# 545                                 Rogue Company         2020
# 546                                The Division 2         2019
#
#                     Genre  TotalEarnings  OnlineEarnings  TotalPlayers  \
# 0                Strategy      191181.81       156839.89           261
# ...

# %%
dataset.shape
# Out:
# (547, 7)

# %%
dataset.head()
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      191181.81
# 1      Age of Empires II         1999  Strategy     2193911.38
# 2     Age of Empires III         2005  Strategy       93299.65
# 3      Age of Empires IV         2021  Strategy        5773.00
# 4  Age of Empires Online         2011  Strategy        5283.56
#
#    OnlineEarnings  TotalPlayers  TotalTournaments
# 0       156839.89           261                99
# 1       719782.87          1467              1085
# 2        41800.00           137               117
# 3            0.00            29                11
# 4          775.00            22                16

# %%
dataset.columns
# Out:
# Index(['Game', 'ReleaseDate', 'Genre', 'TotalEarnings', 'OnlineEarnings',
#        'TotalPlayers', 'TotalTournaments'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Game              547 non-null    object
#  1   ReleaseDate       547 non-null    int64
#  2   Genre             547 non-null    object
#  3   TotalEarnings     547 non-null    float64
#  4   OnlineEarnings    547 non-null    float64
#  5   TotalPlayers      547 non-null    int64
#  6   TotalTournaments  547 non-null    int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 30.0+ KB

# %%
sns.pairplot(dataset)

# %%
dataset = dataset.drop(['Game','ReleaseDate','Genre','TotalTournaments'],axis=1)

# %%
dataset
# Out:
#      TotalEarnings  OnlineEarnings  TotalPlayers
# 0        191181.81       156839.89           261
# 1       2193911.38       719782.87          1467
# 2         93299.65        41800.00           137
# 3          5773.00            0.00            29
# 4          5283.56          775.00            22
# ..             ...             ...           ...
# 542      170000.00       170000.00            39
# 543           0.00            0.00             0
# 544         100.00            0.00             6
# 545       50000.00            0.00            48
# 546       27250.00            0.00            40
#
# [547 rows x 3 columns]

# %%
x = dataset.iloc[:,1]

# %%
x.shape
# Out:
# (547,)

# %%
x
# Out:
# 0      156839.89
# 1      719782.87
# 2       41800.00
# 3           0.00
# 4         775.00
#          ...
# 542    170000.00
# 543         0.00
# 544         0.00
# 545         0.00
# 546         0.00
# Name: OnlineEarnings, Length: 547, dtype: float64

# %%
x = dataset.iloc[:,1].values.reshape(-1,1)

# %%
x.shape
# Out:
# (547, 1)

# %%
x
# Out:
# array([[1.56839890e+05],
#        [7.19782870e+05],
#        [4.18000000e+04],
#        [0.00000000e+00],
#        [7.75000000e+02],
#        [5.20000000e+04],
#        [0.00000000e+00],
#        [1.03552228e+06],
#        [3.36250000e+05],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.12710187e+06],
#        [3.14963898e+06],
#        [5.30866700e+04],
#        [7.95622000e+03],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.19445810e+05],
#        [3.04000000e+04],
#        [0.00000000e+00],
#        [3.19111000e+04],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [4.44857330e+05],
#        [0.00000000e+00],
#        [2.11500000e+05],
#        [0.00000000e+00],
#        [6.96000000e+04],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [2.93428747e+07],
#        [8.07553932e+06],
# ...

# %%
y = dataset.iloc[:,0].values.reshape(-1,1)

# %%
y.shape
# Out:
# (547, 1)

# %%
y
# Out:
# array([[1.91181810e+05],
#        [2.19391138e+06],
#        [9.32996500e+04],
#        [5.77300000e+03],
#        [5.28356000e+03],
#        [9.99410000e+04],
#        [8.60000000e+04],
#        [1.14212028e+06],
#        [1.55795000e+06],
#        [1.82656433e+06],
#        [2.70562543e+06],
#        [2.72085287e+06],
#        [3.36334827e+06],
#        [5.30866700e+04],
#        [8.56122000e+03],
#        [2.00000000e+03],
#        [6.00000000e+04],
#        [2.60241800e+04],
#        [0.00000000e+00],
#        [3.86311880e+05],
#        [3.64000000e+04],
#        [0.00000000e+00],
#        [3.19111000e+04],
#        [1.00000000e+04],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.20626193e+06],
#        [0.00000000e+00],
#        [4.44857330e+05],
#        [3.28665800e+04],
#        [2.11602000e+05],
#        [1.30000000e+04],
#        [6.96000000e+04],
#        [1.00000000e+05],
#        [8.00000000e+02],
#        [3.59118998e+07],
#        [8.50281061e+06],
# ...

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
x_train.shape
# Out:
# (437, 1)

# %%
x_test.shape
# Out:
# (110, 1)

# %%
y_train.shape
# Out:
# (437, 1)

# %%
y_test.shape
# Out:
# (110, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(x_test)

# %%
y_pred
# Out:
# array([[ 5387976.16602474],
#        [ 3958363.67617784],
#        [  317912.97193342],
#        [  306293.24115996],
#        [  311941.30642115],
#        [  306541.75603145],
#        [  306293.24115996],
#        [91726520.78307523],
#        [ 3785927.40784   ],
#        [  487615.45242741],
#        [  306632.12507563],
#        [  306293.24115996],
#        [  306293.24115996],
#        [  315690.19844214],
#        [  371980.24014762],
#        [  557067.33875688],
#        [  758138.4620553 ],
#        [  306293.24115996],
#        [  352099.77338058],
#        [  306293.24115996],
#        [  306293.24115996],
#        [  437824.4247915 ],
#        [  306293.24115996],
#        [  307361.18863567],
#        [  309241.5312263 ],
#        [  306293.24115996],
#        [  337068.23841705],
#        [  306293.24115996],
#        [  591176.64874865],
#        [  306293.24115996],
#        [  306293.24115996],
#        [  306513.51570514],
#        [  306293.24115996],
# ...

# %%
plt.scatter(x,y,color = 'green')
plt.plot(x_test,y_pred,color = 'red')
plt.show()

# %%
final = pd.DataFrame(x_test,columns = ['OnlineEarnings'])

# %%
final['TotalEarnings Actual'] = y_test

# %%
final['TotalEarnings Predicted'] = y_pred

# %%
final
# Out:
#      OnlineEarnings  TotalEarnings Actual  TotalEarnings Predicted
# 0        4498605.00            4560271.00             5.387976e+06
# 1        3233027.83            3242642.34             3.958364e+06
# 2          10286.47              14068.57             3.179130e+05
# 3              0.00              12339.33             3.062932e+05
# 4           5000.00               5000.00             3.119413e+05
# ..              ...                   ...                      ...
# 105       616200.00             820200.00             1.002361e+06
# 106            0.00              50000.00             3.062932e+05
# 107       321008.35             611608.35             6.689085e+05
# 108        35694.54              35694.54             3.466143e+05
# 109            0.00                299.06             3.062932e+05
#
# [110 rows x 3 columns]
